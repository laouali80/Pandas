# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df.head(3)
# Out:
#              qid                                           question  \
# qname
# S0         QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo   QID12                                  Browser Meta Info
# Q310      QID310  <div><span style="font-size:19px;"><strong>You...
#
#          force_resp  type selector
# qname
# S0            False    DB       TB
# MetaInfo      False  Meta  Browser
# Q310          False    DB       TB

# %%
high_salary = (df['ConvertedCompYearly'] > 5000000)

# %%
df.loc[high_salary, ['Country','LanguageHaveWorkedWith','EdLevel']].head(2)
# Out:
#                              Country  \
# ResponseId
# 771         United States of America
# 19680                           Mali
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 771         Bash/Shell (all shells);C;C++;JavaScript;Power...
# 19680                                                     Ada
#
#                                                     EdLevel
# ResponseId
# 771         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 19680        Professional degree (JD, MD, Ph.D, Ed.D, etc.)

# %%
df.head(3)
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                                Remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
# 3           Hobby;Professional development or self-paced l...
#
#                                                  EdLevel  \
# ResponseId
# ...

# %%
countries = ['Canada','Australia','United States of America', 'India']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# ResponseId
# 2        United States of America
# 3        United States of America
# 4        United States of America
# 7        United States of America
# 8        United States of America
#                    ...
# 89165                       India
# 89166                       India
# 89168                       India
# 89176    United States of America
# 89179    United States of America
# Name: Country, Length: 29857, dtype: object

# %%
df.loc[-filt, 'Country']
# Out:
# ResponseId
# 1                                                      NaN
# 5                                              Philippines
# 6        United Kingdom of Great Britain and Northern I...
# 9                                                  Finland
# 15                                             Netherlands
#                                ...
# 89180                                               Brazil
# 89181                                              Romania
# 89182                                               Israel
# 89183                                          Switzerland
# 89184                         Iran, Islamic Republic of...
# Name: Country, Length: 59327, dtype: object

# %%
filt2 = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt2, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object
